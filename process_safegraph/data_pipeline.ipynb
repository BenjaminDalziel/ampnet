# %% [markdown]
# ## Read in and process safegraph data from Ben's engineering drive
# (takes very long)

# %%
# !python3 augment.py "//depot.engr.oregonstate.edu/mime_u1/dalziel/Safe Graph Data" Portland

# %%
import os, sys
import pandas as pd
import polars as pl
import pyarrow
import numpy as np
import json
import time

# %%
data_2019 = '//depot.engr.oregonstate.edu/mime_u1/dalziel/Safe Graph Data/Weekly Patterns/2019_Weekly_Patterns'
test_file = os.path.join((data_2019),os.listdir(data_2019)[13])

# %%
columns = ['safegraph_place_id', 
            'region',
            'city',
            'raw_visit_counts',
            'raw_visitor_counts',
            'visits_by_day',
            'visits_by_each_hour',
            'poi_cbg',
            'visitor_home_cbgs',
            'visitor_daytime_cbgs',
            'distance_from_home',
            'median_dwell',
            'bucketed_dwell_times',
            'date_range_start']

# %%
pl.scan_csv(test_file)
# Out:
# '//depot.engr.oregonstate.edu/mime_u1/dalziel/Safe Graph Data/Weekly Patterns/2019_Weekly_Patterns\\2019-03-18-weekly-patterns.csv.gz'
